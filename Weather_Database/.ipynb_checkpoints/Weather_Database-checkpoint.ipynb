# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description,
                              "Rain inches (last 3hrs)":city_rain,
                                "Snow inches (last 3hrs)":city_snow})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | nouadhibou
# Processing Record 5 of Set 1 | flinders
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | edd
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | north bend
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | horodnya
# Processing Record 19 of Set 1 | sao jose da coroa grande
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | port lincoln
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | shingu
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | lorengau
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | bereda
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | hurghada
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | ambilobe
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | garissa
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | pochutla
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | vadso
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | soyo
# Processing Record 5 of Set 2 | sozimskiy
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | lazaro cardenas
# Processing Record 11 of Set 2 | hirara
# Processing Record 12 of Set 2 | lagoa
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | zhuhai
# Processing Record 17 of Set 2 | cabedelo
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | atikokan
# Processing Record 20 of Set 2 | taoudenni
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | atar
# Processing Record 23 of Set 2 | taltal
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | ucluelet
# Processing Record 31 of Set 2 | pasighat
# Processing Record 32 of Set 2 | knokke-heist
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | taraz
# Processing Record 35 of Set 2 | idil
# Processing Record 36 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | grand gaube
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | prince george
# Processing Record 41 of Set 2 | bamberg
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | roebourne
# Processing Record 44 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | ilam
# Processing Record 48 of Set 2 | vagur
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | arys
# Processing Record 4 of Set 3 | caucaia
# Processing Record 5 of Set 3 | acarau
# Processing Record 6 of Set 3 | bima
# Processing Record 7 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | ongandjera
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | sur
# Processing Record 14 of Set 3 | clifton
# Processing Record 15 of Set 3 | ulladulla
# Processing Record 16 of Set 3 | navolato
# Processing Record 17 of Set 3 | rio grande
# Processing Record 18 of Set 3 | sattahip
# Processing Record 19 of Set 3 | suraabad
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | abu dhabi
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | huarmey
# Processing Record 24 of Set 3 | nuuk
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | mednogorskiy
# Processing Record 27 of Set 3 | muisne
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | tessalit
# Processing Record 30 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | berlevag
# Processing Record 34 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 3 | belmonte
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | la asuncion
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | limburg
# Processing Record 41 of Set 3 | asyut
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | eufaula
# Processing Record 44 of Set 3 | lenger
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | leshukonskoye
# Processing Record 47 of Set 3 | morros
# Processing Record 48 of Set 3 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 49 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 50 of Set 3 | san quintin
# Processing Record 1 of Set 4 | waipawa
# Processing Record 2 of Set 4 | galveston
# Processing Record 3 of Set 4 | syracuse
# Processing Record 4 of Set 4 | bonthe
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | podosinovets
# Processing Record 7 of Set 4 | paungde
# Processing Record 8 of Set 4 | monroe
# Processing Record 9 of Set 4 | cascais
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | acapulco
# Processing Record 12 of Set 4 | lavrentiya
# Processing Record 13 of Set 4 | urubicha
# Processing Record 14 of Set 4 | sabang
# Processing Record 15 of Set 4 | mangrol
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 4 | balkanabat
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | jaciara
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | smithers
# Processing Record 26 of Set 4 | namatanai
# Processing Record 27 of Set 4 | tual
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | cobija
# Processing Record 34 of Set 4 | babol
# Processing Record 35 of Set 4 | littleton
# Processing Record 36 of Set 4 | nabire
# Processing Record 37 of Set 4 | kudahuvadhoo
# Processing Record 38 of Set 4 | sioux lookout
# Processing Record 39 of Set 4 | maldonado
# Processing Record 40 of Set 4 | king city
# Processing Record 41 of Set 4 | urmary
# Processing Record 42 of Set 4 | emerald
# Processing Record 43 of Set 4 | barreirinhas
# Processing Record 44 of Set 4 | whitehorse
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | beloha
# Processing Record 48 of Set 4 | linjiang
# Processing Record 49 of Set 4 | dingle
# Processing Record 50 of Set 4 | muros
# Processing Record 1 of Set 5 | ilulissat
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | haines junction
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | durban
# Processing Record 6 of Set 5 | naryan-mar
# Processing Record 7 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 5 | talara
# Processing Record 9 of Set 5 | orlik
# Processing Record 10 of Set 5 | duluth
# Processing Record 11 of Set 5 | ulaangom
# Processing Record 12 of Set 5 | inhambane
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | grand-santi
# Processing Record 15 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 5 | bethel
# Processing Record 17 of Set 5 | yellowknife
# Processing Record 18 of Set 5 | pimentel
# Processing Record 19 of Set 5 | qiongshan
# Processing Record 20 of Set 5 | maputo
# Processing Record 21 of Set 5 | chaozhou
# Processing Record 22 of Set 5 | san policarpo
# Processing Record 23 of Set 5 | piterka
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | souillac
# Processing Record 26 of Set 5 | atambua
# Processing Record 27 of Set 5 | dikson
# Processing Record 28 of Set 5 | avera
# Processing Record 29 of Set 5 | pavlovka
# Processing Record 30 of Set 5 | kodiak
# Processing Record 31 of Set 5 | richards bay
# Processing Record 32 of Set 5 | nikel
# Processing Record 33 of Set 5 | plettenberg bay
# Processing Record 34 of Set 5 | mayo
# Processing Record 35 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 36 of Set 5 | kidal
# Processing Record 37 of Set 5 | mecca
# Processing Record 38 of Set 5 | kassiopi
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | ouesso
# Processing Record 41 of Set 5 | walldurn
# Processing Record 42 of Set 5 | zhanaozen
# Processing Record 43 of Set 5 | chemax
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | pringsewu
# Processing Record 46 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 47 of Set 5 | nizwa
# Processing Record 48 of Set 5 | kabare
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | timmins
# Processing Record 1 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 6 | kamenka
# Processing Record 4 of Set 6 | dovers
# Processing Record 5 of Set 6 | divo
# Processing Record 6 of Set 6 | eureka
# Processing Record 7 of Set 6 | bastrop
# Processing Record 8 of Set 6 | mali
# Processing Record 9 of Set 6 | nizamabad
# Processing Record 10 of Set 6 | ereymentau
# Processing Record 11 of Set 6 | maragogi
# Processing Record 12 of Set 6 | amapa
# Processing Record 13 of Set 6 | kortkeros
# Processing Record 14 of Set 6 | kaka
# Processing Record 15 of Set 6 | isabela
# Processing Record 16 of Set 6 | westport
# Processing Record 17 of Set 6 | teknaf
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | cuamba
# Processing Record 20 of Set 6 | mayna
# Processing Record 21 of Set 6 | cahul
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | ajaccio
# Processing Record 24 of Set 6 | alice springs
# Processing Record 25 of Set 6 | port-cartier
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | fomboni
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | ola
# Processing Record 30 of Set 6 | vetluzhskiy
# Processing Record 31 of Set 6 | ahuimanu
# Processing Record 32 of Set 6 | srednekolymsk
# Processing Record 33 of Set 6 | novaya igirma
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | zemio
# Processing Record 36 of Set 6 | makakilo city
# Processing Record 37 of Set 6 | northam
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | namibe
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | formosa
# Processing Record 42 of Set 6 | romanovo
# Processing Record 43 of Set 6 | kjollefjord
# Processing Record 44 of Set 6 | likasi
# Processing Record 45 of Set 6 | pointe michel
# Processing Record 46 of Set 6 | leh
# Processing Record 47 of Set 6 | mao
# Processing Record 48 of Set 6 | knysna
# Processing Record 49 of Set 6 | roald
# Processing Record 50 of Set 6 | eyl
# Processing Record 1 of Set 7 | harper
# Processing Record 2 of Set 7 | mogadishu
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | girua
# Processing Record 6 of Set 7 | kamiiso
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | nador
# Processing Record 9 of Set 7 | east london
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | san cristobal
# Processing Record 12 of Set 7 | opotiki
# Processing Record 13 of Set 7 | praia
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | cepu
# Processing Record 16 of Set 7 | morgan city
# Processing Record 17 of Set 7 | inta
# Processing Record 18 of Set 7 | cherskiy
# Processing Record 19 of Set 7 | chokurdakh
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | turka
# Processing Record 22 of Set 7 | turayf
# Processing Record 23 of Set 7 | batagay
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | potosi
# Processing Record 26 of Set 7 | drexel heights
# Processing Record 27 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 7 | marawi
# Processing Record 29 of Set 7 | rantepao
# Processing Record 30 of Set 7 | santa cruz
# Processing Record 31 of Set 7 | paulo ramos
# Processing Record 32 of Set 7 | mayma
# Processing Record 33 of Set 7 | san carlos de bariloche
# Processing Record 34 of Set 7 | hualmay
# Processing Record 35 of Set 7 | mocuba
# Processing Record 36 of Set 7 | cirebon
# Processing Record 37 of Set 7 | ballstad
# City not found. Skipping...
# Processing Record 38 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | sirathu
# Processing Record 41 of Set 7 | carmarthen
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | moose factory
# Processing Record 44 of Set 7 | bichena
# Processing Record 45 of Set 7 | longyearbyen
# Processing Record 46 of Set 7 | baberu
# Processing Record 47 of Set 7 | xining
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | kirakira
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | verkhoyansk
# Processing Record 2 of Set 8 | samarai
# Processing Record 3 of Set 8 | irpa irpa
# Processing Record 4 of Set 8 | markova
# Processing Record 5 of Set 8 | magistralnyy
# Processing Record 6 of Set 8 | bonavista
# Processing Record 7 of Set 8 | livingston
# Processing Record 8 of Set 8 | cockburn town
# Processing Record 9 of Set 8 | bermeo
# Processing Record 10 of Set 8 | porto novo
# Processing Record 11 of Set 8 | naze
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | mollendo
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | killybegs
# Processing Record 18 of Set 8 | mweka
# Processing Record 19 of Set 8 | umm lajj
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | qunduz
# Processing Record 22 of Set 8 | camopi
# Processing Record 23 of Set 8 | jacmel
# Processing Record 24 of Set 8 | steamboat springs
# Processing Record 25 of Set 8 | pucallpa
# Processing Record 26 of Set 8 | puerto morazan
# Processing Record 27 of Set 8 | la ronge
# Processing Record 28 of Set 8 | pyu
# Processing Record 29 of Set 8 | quatre cocos
# Processing Record 30 of Set 8 | pangnirtung
# Processing Record 31 of Set 8 | ambovombe
# Processing Record 32 of Set 8 | virar
# Processing Record 33 of Set 8 | ust-nera
# Processing Record 34 of Set 8 | karonga
# Processing Record 35 of Set 8 | alcantara
# Processing Record 36 of Set 8 | poltar
# Processing Record 37 of Set 8 | mirabela
# Processing Record 38 of Set 8 | luderitz
# Processing Record 39 of Set 8 | saint-louis
# Processing Record 40 of Set 8 | flin flon
# Processing Record 41 of Set 8 | tortoli
# Processing Record 42 of Set 8 | vostok
# Processing Record 43 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 8 | bobcaygeon
# Processing Record 45 of Set 8 | kutum
# Processing Record 46 of Set 8 | mwinilunga
# Processing Record 47 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 8 | chany
# Processing Record 49 of Set 8 | los lunas
# Processing Record 50 of Set 8 | shirokiy
# Processing Record 1 of Set 9 | ketchikan
# Processing Record 2 of Set 9 | maniitsoq
# Processing Record 3 of Set 9 | zalantun
# Processing Record 4 of Set 9 | salinopolis
# Processing Record 5 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 9 | igarka
# Processing Record 7 of Set 9 | karpathos
# Processing Record 8 of Set 9 | mahebourg
# Processing Record 9 of Set 9 | ozernovskiy
# Processing Record 10 of Set 9 | kloulklubed
# Processing Record 11 of Set 9 | deniliquin
# Processing Record 12 of Set 9 | hangzhou
# Processing Record 13 of Set 9 | batsfjord
# Processing Record 14 of Set 9 | havre-saint-pierre
# Processing Record 15 of Set 9 | nishihara
# Processing Record 16 of Set 9 | ardesen
# Processing Record 17 of Set 9 | puerto madryn
# Processing Record 18 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 9 | crnomelj
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | catamarca
# Processing Record 23 of Set 9 | yulara
# Processing Record 24 of Set 9 | paamiut
# Processing Record 25 of Set 9 | marsa matruh
# Processing Record 26 of Set 9 | tazovskiy
# Processing Record 27 of Set 9 | manzhouli
# Processing Record 28 of Set 9 | russell
# Processing Record 29 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 30 of Set 9 | port hardy
# Processing Record 31 of Set 9 | saint-augustin
# Processing Record 32 of Set 9 | mushie
# Processing Record 33 of Set 9 | lugovoy
# Processing Record 34 of Set 9 | dongying
# Processing Record 35 of Set 9 | hatillo
# Processing Record 36 of Set 9 | filadelfia
# Processing Record 37 of Set 9 | nizhniy kuranakh
# Processing Record 38 of Set 9 | halifax
# Processing Record 39 of Set 9 | hinton
# Processing Record 40 of Set 9 | vila velha
# Processing Record 41 of Set 9 | mercedes
# Processing Record 42 of Set 9 | udachnyy
# Processing Record 43 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 9 | la rioja
# Processing Record 45 of Set 9 | kaeo
# Processing Record 46 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 9 | saint-francois
# Processing Record 48 of Set 9 | iberia
# Processing Record 49 of Set 9 | carnot
# Processing Record 50 of Set 9 | caraquet
# Processing Record 1 of Set 10 | port jervis
# Processing Record 2 of Set 10 | vanimo
# Processing Record 3 of Set 10 | damavand
# Processing Record 4 of Set 10 | san jose
# Processing Record 5 of Set 10 | tateyama
# Processing Record 6 of Set 10 | sailana
# Processing Record 7 of Set 10 | santa rosa
# Processing Record 8 of Set 10 | texarkana
# Processing Record 9 of Set 10 | college
# Processing Record 10 of Set 10 | asau
# Processing Record 11 of Set 10 | raga
# Processing Record 12 of Set 10 | kalmanka
# Processing Record 13 of Set 10 | baracoa
# Processing Record 14 of Set 10 | oktyabrskoye
# Processing Record 15 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 10 | surami
# Processing Record 17 of Set 10 | la ciotat
# Processing Record 18 of Set 10 | zyryanka
# Processing Record 19 of Set 10 | assomada
# Processing Record 20 of Set 10 | hohhot
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | jawhar
# Processing Record 23 of Set 10 | chumphon
# Processing Record 24 of Set 10 | pemba
# Processing Record 25 of Set 10 | karasburg
# Processing Record 26 of Set 10 | haverfordwest
# Processing Record 27 of Set 10 | qarayeri
# Processing Record 28 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 10 | fasa
# Processing Record 30 of Set 10 | husavik
# Processing Record 31 of Set 10 | sidi ali
# Processing Record 32 of Set 10 | princeton
# Processing Record 33 of Set 10 | meiganga
# Processing Record 34 of Set 10 | barinas
# Processing Record 35 of Set 10 | brae
# Processing Record 36 of Set 10 | kolondieba
# Processing Record 37 of Set 10 | acatic
# Processing Record 38 of Set 10 | krasnoselkup
# Processing Record 39 of Set 10 | linhares
# Processing Record 40 of Set 10 | ruteng
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 43 of Set 10 | belle fourche
# Processing Record 44 of Set 10 | lebyazhye
# Processing Record 45 of Set 10 | dzhebariki-khaya
# Processing Record 46 of Set 10 | grindavik
# Processing Record 47 of Set 10 | vardo
# Processing Record 48 of Set 10 | ryotsu
# Processing Record 49 of Set 10 | burica
# City not found. Skipping...
# Processing Record 50 of Set 10 | palauig
# Processing Record 1 of Set 11 | mulanje
# Processing Record 2 of Set 11 | mitsamiouli
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | vao
# Processing Record 5 of Set 11 | oberkirch
# Processing Record 6 of Set 11 | krasnyy chikoy
# Processing Record 7 of Set 11 | mae hong son
# Processing Record 8 of Set 11 | qasigiannguit
# Processing Record 9 of Set 11 | lexington
# Processing Record 10 of Set 11 | beringovskiy
# Processing Record 11 of Set 11 | karamadai
# Processing Record 12 of Set 11 | pangody
# Processing Record 13 of Set 11 | ahome
# Processing Record 14 of Set 11 | tselina
# Processing Record 15 of Set 11 | bardsir
# Processing Record 16 of Set 11 | jalu
# Processing Record 17 of Set 11 | praia da vitoria
# Processing Record 18 of Set 11 | bashtanka
# Processing Record 19 of Set 11 | tilichiki
# Processing Record 20 of Set 11 | maddur
# Processing Record 21 of Set 11 | kavieng
# Processing Record 22 of Set 11 | gamba
# Processing Record 23 of Set 11 | buchanan
# Processing Record 24 of Set 11 | bumba
# Processing Record 25 of Set 11 | sinnamary
# Processing Record 26 of Set 11 | itupiranga
# Processing Record 27 of Set 11 | longavi
# Processing Record 28 of Set 11 | stromness
# Processing Record 29 of Set 11 | chapais
# Processing Record 30 of Set 11 | qaqortoq
# Processing Record 31 of Set 11 | esna
# Processing Record 32 of Set 11 | grojec
# Processing Record 33 of Set 11 | grants pass
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | yangjiang
# Processing Record 36 of Set 11 | okato
# Processing Record 37 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 38 of Set 11 | guiglo
# Processing Record 39 of Set 11 | chengdu
# Processing Record 40 of Set 11 | marfino
# Processing Record 41 of Set 11 | pincher creek
# Processing Record 42 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 11 | sterlibashevo
# Processing Record 44 of Set 11 | ichinohe
# Processing Record 45 of Set 11 | chulumani
# Processing Record 46 of Set 11 | tulle
# Processing Record 47 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 11 | hofn
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | luanda
# Processing Record 1 of Set 12 | boca do acre
# Processing Record 2 of Set 12 | placido de castro
# Processing Record 3 of Set 12 | kaputa
# Processing Record 4 of Set 12 | kodinsk
# Processing Record 5 of Set 12 | srivardhan
# Processing Record 6 of Set 12 | arya
# Processing Record 7 of Set 12 | lidkoping
# Processing Record 8 of Set 12 | ayagoz
# Processing Record 9 of Set 12 | staryy nadym
# Processing Record 10 of Set 12 | dawei
# Processing Record 11 of Set 12 | cabo rojo
# Processing Record 12 of Set 12 | southbridge
# Processing Record 13 of Set 12 | lamu
# Processing Record 14 of Set 12 | shieli
# Processing Record 15 of Set 12 | ushtobe
# Processing Record 16 of Set 12 | baghdad
# Processing Record 17 of Set 12 | okha
# Processing Record 18 of Set 12 | lerwick
# Processing Record 19 of Set 12 | la palma
# Processing Record 20 of Set 12 | xiuyan
# Processing Record 21 of Set 12 | pemangkat
# Processing Record 22 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 23 of Set 12 | khao wong
# Processing Record 24 of Set 12 | hamilton
# Processing Record 25 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 12 | san ramon de la nueva oran
# Processing Record 27 of Set 12 | myre
# Processing Record 28 of Set 12 | zabid
# Processing Record 29 of Set 12 | brunswick
# Processing Record 30 of Set 12 | saint-pierre
# Processing Record 31 of Set 12 | olavarria
# Processing Record 32 of Set 12 | capreol
# Processing Record 33 of Set 12 | shakiso
# Processing Record 34 of Set 12 | zhangjiakou
# Processing Record 35 of Set 12 | posse
# Processing Record 36 of Set 12 | marrakesh
# Processing Record 37 of Set 12 | karratha
# Processing Record 38 of Set 12 | nerchinskiy zavod
# Processing Record 39 of Set 12 | lander
# Processing Record 40 of Set 12 | yarada
# Processing Record 41 of Set 12 | caceres
# Processing Record 42 of Set 12 | kimbe
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | solnechnyy
# Processing Record 45 of Set 12 | nizhnevartovsk
# Processing Record 46 of Set 12 | kubinka
# Processing Record 47 of Set 12 | camacari
# Processing Record 48 of Set 12 | orkney
# Processing Record 49 of Set 12 | vestmanna
# Processing Record 50 of Set 12 | casablanca
# Processing Record 1 of Set 13 | lodja
# Processing Record 2 of Set 13 | whyalla
# Processing Record 3 of Set 13 | pingliang
# Processing Record 4 of Set 13 | puerto baquerizo moreno
# Processing Record 5 of Set 13 | vigrestad
# Processing Record 6 of Set 13 | qiyang
# Processing Record 7 of Set 13 | saint-georges
# Processing Record 8 of Set 13 | yerbogachen
# Processing Record 9 of Set 13 | las margaritas
# Processing Record 10 of Set 13 | santa fe
# Processing Record 11 of Set 13 | muromtsevo
# Processing Record 12 of Set 13 | alta floresta
# Processing Record 13 of Set 13 | mbandaka
# Processing Record 14 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 13 | kirkwall
# Processing Record 16 of Set 13 | kingston
# Processing Record 17 of Set 13 | bol
# Processing Record 18 of Set 13 | dukat
# Processing Record 19 of Set 13 | vieques
# Processing Record 20 of Set 13 | trabzon
# Processing Record 21 of Set 13 | verkh-usugli
# Processing Record 22 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | belaya gora
# Processing Record 24 of Set 13 | alegrete
# Processing Record 25 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 13 | olinda
# Processing Record 27 of Set 13 | nadvoitsy
# Processing Record 28 of Set 13 | le port
# Processing Record 29 of Set 13 | minot
# Processing Record 30 of Set 13 | palmer
# Processing Record 31 of Set 13 | dalbandin
# Processing Record 32 of Set 13 | diamantino
# Processing Record 33 of Set 13 | ladario
# Processing Record 34 of Set 13 | gubkinskiy
# Processing Record 35 of Set 13 | marquette
# Processing Record 36 of Set 13 | antalaha
# Processing Record 37 of Set 13 | tigil
# Processing Record 38 of Set 13 | robertsport
# Processing Record 39 of Set 13 | bardiyah
# Processing Record 40 of Set 13 | jizan
# Processing Record 41 of Set 13 | kurilsk
# Processing Record 42 of Set 13 | mindelo
# Processing Record 43 of Set 13 | ixtapa
# Processing Record 44 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 13 | labuhan
# Processing Record 46 of Set 13 | prince rupert
# Processing Record 47 of Set 13 | marzuq
# Processing Record 48 of Set 13 | bukachacha
# Processing Record 49 of Set 13 | limoges
# Processing Record 50 of Set 13 | aswan
# Processing Record 1 of Set 14 | elbistan
# Processing Record 2 of Set 14 | rafai
# Processing Record 3 of Set 14 | ayan
# Processing Record 4 of Set 14 | minyar
# Processing Record 5 of Set 14 | pinyug
# Processing Record 6 of Set 14 | myitkyina
# Processing Record 7 of Set 14 | bathsheba
# Processing Record 8 of Set 14 | goderich
# Processing Record 9 of Set 14 | carora
# Processing Record 10 of Set 14 | cristobal obregon
# Processing Record 11 of Set 14 | gobabis
# Processing Record 12 of Set 14 | willmar
# Processing Record 13 of Set 14 | sydney
# Processing Record 14 of Set 14 | maralal
# Processing Record 15 of Set 14 | zwedru
# Processing Record 16 of Set 14 | altay
# Processing Record 17 of Set 14 | san matias
# Processing Record 18 of Set 14 | brasilia de minas
# Processing Record 19 of Set 14 | carballo
# Processing Record 20 of Set 14 | lasa
# Processing Record 21 of Set 14 | birjand
# Processing Record 22 of Set 14 | xinyu
# Processing Record 23 of Set 14 | greece
# Processing Record 24 of Set 14 | nemuro
# Processing Record 25 of Set 14 | kampene
# Processing Record 26 of Set 14 | kushima
# Processing Record 27 of Set 14 | kisangani
# Processing Record 28 of Set 14 | guayaramerin
# Processing Record 29 of Set 14 | rybinsk
# Processing Record 30 of Set 14 | progreso
# Processing Record 31 of Set 14 | isangel
# Processing Record 32 of Set 14 | bairiki
# Processing Record 33 of Set 14 | pangoa
# Processing Record 34 of Set 14 | tautira
# Processing Record 35 of Set 14 | mwanza
# Processing Record 36 of Set 14 | ribas do rio pardo
# Processing Record 37 of Set 14 | pombas
# Processing Record 38 of Set 14 | prado
# Processing Record 39 of Set 14 | cavalcante
# Processing Record 40 of Set 14 | ahipara
# Processing Record 41 of Set 14 | gravdal
# Processing Record 42 of Set 14 | tsiroanomandidy
# Processing Record 43 of Set 14 | teruel
# Processing Record 44 of Set 14 | wakefield
# Processing Record 45 of Set 14 | campo grande
# Processing Record 46 of Set 14 | champerico
# Processing Record 47 of Set 14 | chicama
# Processing Record 48 of Set 14 | broome
# Processing Record 49 of Set 14 | dicabisagan
# Processing Record 50 of Set 14 | deputatskiy
# Processing Record 1 of Set 15 | anastasiyevskaya
# Processing Record 2 of Set 15 | tupik
# Processing Record 3 of Set 15 | tuatapere
# Processing Record 4 of Set 15 | waddan
# Processing Record 5 of Set 15 | nowy targ
# Processing Record 6 of Set 15 | aitape
# Processing Record 7 of Set 15 | kalaleh
# Processing Record 8 of Set 15 | krasnogvardeyskiy
# Processing Record 9 of Set 15 | colares
# Processing Record 10 of Set 15 | maoming
# Processing Record 11 of Set 15 | develi
# Processing Record 12 of Set 15 | sinfra
# Processing Record 13 of Set 15 | lewisville
# Processing Record 14 of Set 15 | tarpon springs
# Processing Record 15 of Set 15 | chililabombwe
# Processing Record 16 of Set 15 | san miguel
# Processing Record 17 of Set 15 | goteborg
# City not found. Skipping...
# Processing Record 18 of Set 15 | arrifes
# Processing Record 19 of Set 15 | champagnole
# Processing Record 20 of Set 15 | coquimbo
# Processing Record 21 of Set 15 | dergachi
# Processing Record 22 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 23 of Set 15 | praya
# Processing Record 24 of Set 15 | okhotsk
# Processing Record 25 of Set 15 | wanaka
# Processing Record 26 of Set 15 | ojinaga
# Processing Record 27 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 15 | perevoz
# Processing Record 29 of Set 15 | chunoyar
# Processing Record 30 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 15 | chebsara
# Processing Record 32 of Set 15 | mehamn
# Processing Record 33 of Set 15 | young
# Processing Record 34 of Set 15 | cumberland
# Processing Record 35 of Set 15 | juigalpa
# Processing Record 36 of Set 15 | ibipeba
# Processing Record 37 of Set 15 | talnakh
# Processing Record 38 of Set 15 | ornes
# Processing Record 39 of Set 15 | kununurra
# Processing Record 40 of Set 15 | ngunguru
# Processing Record 41 of Set 15 | castelo do piaui
# Processing Record 42 of Set 15 | mount isa
# Processing Record 43 of Set 15 | shevchenkove
# Processing Record 44 of Set 15 | elk plain
# Processing Record 45 of Set 15 | melfi
# Processing Record 46 of Set 15 | sisimiut
# Processing Record 47 of Set 15 | aliwal north
# Processing Record 48 of Set 15 | estevan
# Processing Record 49 of Set 15 | tekirdag
# Processing Record 50 of Set 15 | ottawa
# Processing Record 1 of Set 16 | chokwe
# Processing Record 2 of Set 16 | ipeti
# City not found. Skipping...
# Processing Record 3 of Set 16 | linshu
# City not found. Skipping...
# Processing Record 4 of Set 16 | lobanovo
# Processing Record 5 of Set 16 | port moresby
# Processing Record 6 of Set 16 | kijang
# Processing Record 7 of Set 16 | esso
# Processing Record 8 of Set 16 | morondava
# Processing Record 9 of Set 16 | borogontsy
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
city_data
# Out:
# [{'City': 'Albany',
#   'Country': 'US',
#   'Date': '2022-07-18 04:36:05',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 73.67,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Date': '2022-07-18 04:40:01',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.43,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 15.3,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:01',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 67.01,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Date': '2022-07-18 04:40:02',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 71.58,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 26.46,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:02',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 62.38,
#   'Humidity': 45,
#   'Cloudiness': 2,
#   'Wind Speed': 10,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Date': '2022-07-18 04:40:02',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 33.91,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Date': '2022-07-18 04:39:13',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 70.05,
#   'Humidity': 50,
#   'Cloudiness': 11,
#   'Wind Speed': 3.62,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:03',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.87,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 11.63,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Date': '2022-07-18 04:40:03',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 83.5,
#   'Humidity': 72,
#   'Cloudiness': 25,
#   'Wind Speed': 10.98,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Date': '2022-07-18 04:38:29',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.56,
#   'Humidity': 91,
#   'Cloudiness': 71,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:40:04',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 53.8,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 8.81,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:04',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 43.02,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 0.87,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Edd',
#   'Country': 'ER',
#   'Date': '2022-07-18 04:40:05',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 92.26,
#   'Humidity': 47,
#   'Cloudiness': 89,
#   'Wind Speed': 4.09,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:05',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 64.02,
#   'Humidity': 67,
#   'Cloudiness': 86,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:05',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 59.16,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:06',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 70.81,
#   'Humidity': 54,
#   'Cloudiness': 28,
#   'Wind Speed': 12.86,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:06',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.38,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Horodnya',
#   'Country': 'UA',
#   'Date': '2022-07-18 04:40:06',
#   'Lat': 51.8909,
#   'Lng': 31.5974,
#   'Max Temp': 56.19,
#   'Humidity': 87,
#   'Cloudiness': 61,
#   'Wind Speed': 8.84,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:06',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 73.31,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 8.3,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:07',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 56.88,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 10.6,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:07',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 54.09,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:08',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 43.72,
#   'Humidity': 80,
#   'Cloudiness': 87,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:39:03',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 56.32,
#   'Humidity': 96,
#   'Cloudiness': 3,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:39:23',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 85.51,
#   'Humidity': 63,
#   'Cloudiness': 46,
#   'Wind Speed': 4.52,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Date': '2022-07-18 04:39:04',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 89.31,
#   'Humidity': 52,
#   'Cloudiness': 97,
#   'Wind Speed': 10.36,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Date': '2022-07-18 04:40:08',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 89.53,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Current Description': 'haze',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:08',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 40.42,
#   'Humidity': 70,
#   'Cloudiness': 41,
#   'Wind Speed': 1.81,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Date': '2022-07-18 04:35:21',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 83.48,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 9.08,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:40:09',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 62.19,
#   'Humidity': 47,
#   'Cloudiness': 3,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Date': '2022-07-18 04:39:23',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 31.66,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Date': '2022-07-18 04:40:09',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.97,
#   'Humidity': 75,
#   'Cloudiness': 21,
#   'Wind Speed': 21.07,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Date': '2022-07-18 04:40:09',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 85.28,
#   'Humidity': 62,
#   'Cloudiness': 7,
#   'Wind Speed': 4.07,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bereda',
#   'Country': 'ES',
#   'Date': '2022-07-18 04:40:10',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 66.58,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 1.45,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:10',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 50.74,
#   'Humidity': 59,
#   'Cloudiness': 74,
#   'Wind Speed': 8.46,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Date': '2022-07-18 04:40:10',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 57.02,
#   'Humidity': 88,
#   'Cloudiness': 38,
#   'Wind Speed': 4.61,
#   'Current Description': 'mist',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hurghada',
#   'Country': 'EG',
#   'Date': '2022-07-18 04:40:11',
#   'Lat': 27.2574,
#   'Lng': 33.8129,
#   'Max Temp': 80.64,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:40:11',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 54.14,
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 1.81,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Date': '2022-07-18 04:40:07',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 91.96,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:40:11',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 54.36,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 6.51,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ambilobe',
#   'Country': 'MG',
#   'Date': '2022-07-18 04:40:12',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 75.29,
#   'Humidity': 47,
#   'Cloudiness': 11,
#   'Wind Speed': 8.52,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:12',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 41.36,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 17.9,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Garissa',
#   'Country': 'KE',
#   'Date': '2022-07-18 04:40:12',
#   'Lat': -0.4536,
#   'Lng': 39.6401,
#   'Max Temp': 74.19,
#   'Humidity': 70,
#   'Cloudiness': 25,
#   'Wind Speed': 18.54,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Date': '2022-07-18 04:40:13',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 51.1,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:40:13',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 77.83,
#   'Humidity': 93,
#   'Cloudiness': 65,
#   'Wind Speed': 4.27,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:13',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 53.44,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 13.44,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vadso',
#   'Country': 'NO',
#   'Date': '2022-07-18 04:40:13',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 61.68,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Date': '2022-07-18 04:40:14',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.93,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 15.73,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:40:14',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 71.31,
#   'Humidity': 95,
#   'Cloudiness': 6,
#   'Wind Speed': 6.89,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Date': '2022-07-18 04:39:27',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 75.31,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'fog',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Date': '2022-07-18 04:40:14',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Soyo',
#   'Country': 'AO',
#   'Date': '2022-07-18 04:40:15',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 70.23,
#   'Humidity': 87,
#   'Cloudiness': 72,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sozimskiy',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:15',
#   'Lat': 59.7418,
#   'Lng': 52.2482,
#   'Max Temp': 66.13,
#   'Humidity': 69,
#   'Cloudiness': 87,
#   'Wind Speed': 1.36,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:40:15',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 53.47,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 8.21,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Date': '2022-07-18 04:40:16',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 82.96,
#   'Humidity': 72,
#   'Cloudiness': 91,
#   'Wind Speed': 13.85,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:40:16',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 72.01,
#   'Humidity': 81,
#   'Cloudiness': 15,
#   'Wind Speed': 6.15,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Date': '2022-07-18 04:40:16',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.36,
#   'Humidity': 73,
#   'Cloudiness': 13,
#   'Wind Speed': 13.6,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lazaro Cardenas',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:40:16',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 78.24,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 3.65,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Date': '2022-07-18 04:40:17',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 88.07,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:36:36',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 69.91,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:40:17',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 6,
#   'Wind Speed': 7.56,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:37:05',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 44.26,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Date': '2022-07-18 04:40:18',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 73.29,
#   'Humidity': 81,
#   'Cloudiness': 55,
#   'Wind Speed': 12.88,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Zhuhai',
#   'Country': 'CN',
#   'Date': '2022-07-18 04:40:18',
#   'Lat': 22.2769,
#   'Lng': 113.5678,
#   'Max Temp': 99.86,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:18',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 70.47,
#   'Humidity': 77,
#   'Cloudiness': 10,
#   'Wind Speed': 12.01,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:40:18',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 50.68,
#   'Humidity': 87,
#   'Cloudiness': 3,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Atikokan',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:19',
#   'Lat': 48.7555,
#   'Lng': -91.6216,
#   'Max Temp': 66.15,
#   'Humidity': 91,
#   'Cloudiness': 5,
#   'Wind Speed': 5.32,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Date': '2022-07-18 04:40:19',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 91.94,
#   'Humidity': 9,
#   'Cloudiness': 40,
#   'Wind Speed': 7.43,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Date': '2022-07-18 04:40:19',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.22,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Date': '2022-07-18 04:40:20',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 87.04,
#   'Humidity': 36,
#   'Cloudiness': 36,
#   'Wind Speed': 2.66,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Date': '2022-07-18 04:40:20',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 57.56,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 0.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:20',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 37.22,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 5.08,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:20',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 41.63,
#   'Humidity': 93,
#   'Cloudiness': 36,
#   'Wind Speed': 8.28,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Date': '2022-07-18 04:40:21',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:21',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 56.97,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:21',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 57.09,
#   'Humidity': 92,
#   'Cloudiness': 91,
#   'Wind Speed': 6.15,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:08',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 56.37,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.56,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ucluelet',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:22',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 58.08,
#   'Humidity': 89,
#   'Cloudiness': 5,
#   'Wind Speed': 5.35,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pasighat',
#   'Country': 'IN',
#   'Date': '2022-07-18 04:40:22',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 81.16,
#   'Humidity': 96,
#   'Cloudiness': 87,
#   'Wind Speed': 3.98,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Knokke-Heist',
#   'Country': 'BE',
#   'Date': '2022-07-18 04:40:22',
#   'Lat': 51.3333,
#   'Lng': 3.3333,
#   'Max Temp': 65.44,
#   'Humidity': 62,
#   'Cloudiness': 64,
#   'Wind Speed': 7.16,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:22',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 84.27,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Taraz',
#   'Country': 'KZ',
#   'Date': '2022-07-18 04:40:23',
#   'Lat': 42.9,
#   'Lng': 71.3667,
#   'Max Temp': 86.41,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Idil',
#   'Country': 'TR',
#   'Date': '2022-07-18 04:40:23',
#   'Lat': 37.3411,
#   'Lng': 41.8895,
#   'Max Temp': 82.33,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:23',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 97.39,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Date': '2022-07-18 04:40:24',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 71.38,
#   'Humidity': 70,
#   'Cloudiness': 55,
#   'Wind Speed': 14,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Date': '2022-07-18 04:40:24',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 77.09,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'light intensity drizzle',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Prince George',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:24',
#   'Lat': 53.9166,
#   'Lng': -122.753,
#   'Max Temp': 62.29,
#   'Humidity': 69,
#   'Cloudiness': 12,
#   'Wind Speed': 1.43,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bamberg',
#   'Country': 'DE',
#   'Date': '2022-07-18 04:40:25',
#   'Lat': 49.8795,
#   'Lng': 10.8863,
#   'Max Temp': 57.52,
#   'Humidity': 58,
#   'Cloudiness': 33,
#   'Wind Speed': 2.01,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:25',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 65.52,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 5.48,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Roebourne',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:37:21',
#   'Lat': -20.7833,
#   'Lng': 117.1333,
#   'Max Temp': 79.21,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Date': '2022-07-18 04:40:25',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 50.92,
#   'Humidity': 87,
#   'Cloudiness': 50,
#   'Wind Speed': 14.07,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ilam',
#   'Country': 'NP',
#   'Date': '2022-07-18 04:40:26',
#   'Lat': 26.9167,
#   'Lng': 87.9167,
#   'Max Temp': 79.11,
#   'Humidity': 78,
#   'Cloudiness': 67,
#   'Wind Speed': 5.03,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Vagur',
#   'Country': 'FO',
#   'Date': '2022-07-18 04:40:26',
#   'Lat': 61.4732,
#   'Lng': -6.8119,
#   'Max Temp': 50.4,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 15.05,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Date': '2022-07-18 04:40:26',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 94.44,
#   'Humidity': 12,
#   'Cloudiness': 41,
#   'Wind Speed': 7.92,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:27',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 41.58,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:35:28',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 62.38,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:27',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 72.77,
#   'Humidity': 83,
#   'Cloudiness': 15,
#   'Wind Speed': 12.62,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Arys',
#   'Country': 'KZ',
#   'Date': '2022-07-18 04:40:27',
#   'Lat': 42.4252,
#   'Lng': 68.795,
#   'Max Temp': 97.47,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 18.61,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Caucaia',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:37:30',
#   'Lat': -3.7361,
#   'Lng': -38.6531,
#   'Max Temp': 79.03,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:28',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 77.45,
#   'Humidity': 80,
#   'Cloudiness': 5,
#   'Wind Speed': 15.28,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bima',
#   'Country': 'ID',
#   'Date': '2022-07-18 04:40:28',
#   'Lat': -8.4667,
#   'Lng': 118.7167,
#   'Max Temp': 86.67,
#   'Humidity': 56,
#   'Cloudiness': 76,
#   'Wind Speed': 6.26,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:28',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 61.72,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 9.84,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:29',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 61.21,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Date': '2022-07-18 04:36:53',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 41.02,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ongandjera',
#   'Country': 'NA',
#   'Date': '2022-07-18 04:40:29',
#   'Lat': -17.8833,
#   'Lng': 15.0667,
#   'Max Temp': 51.04,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.28,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:38:59',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 57.27,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Date': '2022-07-18 04:40:29',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 80.31,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.78,
#   'Current Description': 'heavy intensity rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Clifton',
#   'Country': 'US',
#   'Date': '2022-07-18 04:38:42',
#   'Lat': 40.8584,
#   'Lng': -74.1638,
#   'Max Temp': 80.04,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ulladulla',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:40:30',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 58.53,
#   'Humidity': 39,
#   'Cloudiness': 14,
#   'Wind Speed': 5.39,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Navolato',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:39:31',
#   'Lat': 24.7672,
#   'Lng': -107.6944,
#   'Max Temp': 84.38,
#   'Humidity': 77,
#   'Cloudiness': 53,
#   'Wind Speed': 4.36,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:30',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 46.08,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.88,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sattahip',
#   'Country': 'TH',
#   'Date': '2022-07-18 04:40:30',
#   'Lat': 12.6664,
#   'Lng': 100.9007,
#   'Max Temp': 93.97,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Suraabad',
#   'Country': 'AZ',
#   'Date': '2022-07-18 04:40:31',
#   'Lat': 40.8192,
#   'Lng': 49.4687,
#   'Max Temp': 85.6,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 9.66,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Date': '2022-07-18 04:40:31',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 91.29,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 1.92,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Abu Dhabi',
#   'Country': 'AE',
#   'Date': '2022-07-18 04:36:07',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 96.91,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Date': '2022-07-18 04:40:31',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 61.97,
#   'Humidity': 86,
#   'Cloudiness': 44,
#   'Wind Speed': 7.9,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:32',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 45.21,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Date': '2022-07-18 04:40:32',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 85.1,
#   'Humidity': 64,
#   'Cloudiness': 56,
#   'Wind Speed': 6.06,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mednogorskiy',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:32',
#   'Lat': 43.9178,
#   'Lng': 41.1825,
#   'Max Temp': 67.3,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 2.04,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Muisne',
#   'Country': 'EC',
#   'Date': '2022-07-18 04:40:32',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 73.67,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.61,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Date': '2022-07-18 04:40:33',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 87.4,
#   'Humidity': 41,
#   'Cloudiness': 95,
#   'Wind Speed': 9.44,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Date': '2022-07-18 04:40:33',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 78.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 1.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Date': '2022-07-18 04:40:34',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 55.2,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Belmonte',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:34',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 72.18,
#   'Humidity': 85,
#   'Cloudiness': 49,
#   'Wind Speed': 9.1,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Date': '2022-07-18 04:40:34',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 77.25,
#   'Humidity': 69,
#   'Cloudiness': 79,
#   'Wind Speed': 17.13,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'La Asuncion',
#   'Country': 'VE',
#   'Date': '2022-07-18 04:40:35',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 78.53,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 14.97,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:35',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 69.87,
#   'Humidity': 44,
#   'Cloudiness': 96,
#   'Wind Speed': 9.82,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Limburg',
#   'Country': 'NL',
#   'Date': '2022-07-18 04:39:21',
#   'Lat': 51.25,
#   'Lng': 6,
#   'Max Temp': 62.31,
#   'Humidity': 84,
#   'Cloudiness': 59,
#   'Wind Speed': 5.35,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Asyut',
#   'Country': 'EG',
#   'Date': '2022-07-18 04:40:35',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 75.38,
#   'Humidity': 39,
#   'Cloudiness': 7,
#   'Wind Speed': 7.52,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Date': '2022-07-18 04:40:36',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 67.59,
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 22.37,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Eufaula',
#   'Country': 'US',
#   'Date': '2022-07-18 04:36:18',
#   'Lat': 31.8913,
#   'Lng': -85.1455,
#   'Max Temp': 75.85,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lenger',
#   'Country': 'KZ',
#   'Date': '2022-07-18 04:40:36',
#   'Lat': 42.183,
#   'Lng': 69.8839,
#   'Max Temp': 90.84,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Date': '2022-07-18 04:40:36',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 44.65,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 6.15,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:37',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 62.55,
#   'Humidity': 66,
#   'Cloudiness': 97,
#   'Wind Speed': 5.59,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Morros',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:37',
#   'Lat': -9.4467,
#   'Lng': -46.3003,
#   'Max Temp': 64.99,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 3.96,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:40:37',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 67.77,
#   'Humidity': 84,
#   'Cloudiness': 6,
#   'Wind Speed': 5.35,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:40:38',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 50.94,
#   'Humidity': 75,
#   'Cloudiness': 78,
#   'Wind Speed': 18.3,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Galveston',
#   'Country': 'US',
#   'Date': '2022-07-18 04:39:16',
#   'Lat': 29.3669,
#   'Lng': -94.9669,
#   'Max Temp': 84.96,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Syracuse',
#   'Country': 'IT',
#   'Date': '2022-07-18 04:40:38',
#   'Lat': 37.0881,
#   'Lng': 15.2792,
#   'Max Temp': 71.19,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Date': '2022-07-18 04:40:38',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 76.51,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 14.38,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:38',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 1.48,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Podosinovets',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:40:39',
#   'Lat': 60.2776,
#   'Lng': 47.0659,
#   'Max Temp': 66.88,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Paungde',
#   'Country': 'MM',
#   'Date': '2022-07-18 04:40:39',
#   'Lat': 18.4833,
#   'Lng': 95.5,
#   'Max Temp': 88.99,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Monroe',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:35',
#   'Lat': 43.1501,
#   'Lng': -77.6831,
#   'Max Temp': 73.96,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cascais',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:40:39',
#   'Lat': 38.6979,
#   'Lng': -9.4215,
#   'Max Temp': 67.96,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:39:32',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 58.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.67,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:40:40',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 82.22,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:38:58',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 40.23,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 25.81,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Urubicha',
#   'Country': 'BO',
#   'Date': '2022-07-18 04:40:11',
#   'Lat': -15.3833,
#   'Lng': -62.95,
#   'Max Temp': 62.64,
#   'Humidity': 74,
#   'Cloudiness': 18,
#   'Wind Speed': 2.39,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sabang',
#   'Country': 'ID',
#   'Date': '2022-07-18 04:40:40',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 82.69,
#   'Humidity': 71,
#   'Cloudiness': 41,
#   'Wind Speed': 7.52,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mangrol',
#   'Country': 'IN',
#   'Date': '2022-07-18 04:40:41',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 82.78,
#   'Humidity': 78,
#   'Cloudiness': 88,
#   'Wind Speed': 13.78,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:41',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 77.07,
#   'Humidity': 81,
#   'Cloudiness': 5,
#   'Wind Speed': 14.23,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Balkanabat',
#   'Country': 'TM',
#   'Date': '2022-07-18 04:40:41',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 93.07,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.93,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Date': '2022-07-18 04:40:41',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 41.23,
#   'Humidity': 74,
#   'Cloudiness': 37,
#   'Wind Speed': 7.02,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Jaciara',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:40:42',
#   'Lat': -15.9653,
#   'Lng': -54.9683,
#   'Max Temp': 66.69,
#   'Humidity': 71,
#   'Cloudiness': 5,
#   'Wind Speed': 2.82,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Date': '2022-07-18 04:40:42',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 73.29,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Date': '2022-07-18 04:37:47',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 71.55,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'mist',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:40:42',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 39.29,
#   'Humidity': 93,
#   'Cloudiness': 81,
#   'Wind Speed': 8.95,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Date': '2022-07-18 04:40:43',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 60.48,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Smithers',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:40:43',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 53.71,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 4.54,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Namatanai',
# ...
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Anastasiyevskaya',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:42:58',
#   'Lat': 45.2158,
#   'Lng': 37.8926,
#   'Max Temp': 73.89,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 14.74,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tupik',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:42:58',
#   'Lat': 54.4253,
#   'Lng': 119.9327,
#   'Max Temp': 71.56,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:42:59',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 52.47,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Waddan',
#   'Country': 'LY',
#   'Date': '2022-07-18 04:42:59',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 74.32,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 4.27,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Nowy Targ',
#   'Country': 'PL',
#   'Date': '2022-07-18 04:42:59',
#   'Lat': 49.4778,
#   'Lng': 20.0323,
#   'Max Temp': 53.74,
#   'Humidity': 64,
#   'Cloudiness': 45,
#   'Wind Speed': 2.8,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Aitape',
#   'Country': 'PG',
#   'Date': '2022-07-18 04:43:00',
#   'Lat': -3.1374,
#   'Lng': 142.3475,
#   'Max Temp': 83.75,
#   'Humidity': 73,
#   'Cloudiness': 72,
#   'Wind Speed': 6.58,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kalaleh',
#   'Country': 'IR',
#   'Date': '2022-07-18 04:43:00',
#   'Lat': 37.3807,
#   'Lng': 55.4916,
#   'Max Temp': 86.36,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Krasnogvardeyskiy',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:00',
#   'Lat': 57.3793,
#   'Lng': 62.3195,
#   'Max Temp': 72.27,
#   'Humidity': 60,
#   'Cloudiness': 10,
#   'Wind Speed': 3.15,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Colares',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:43:01',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 67.78,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Maoming',
#   'Country': 'CN',
#   'Date': '2022-07-18 04:43:01',
#   'Lat': 21.65,
#   'Lng': 110.9,
#   'Max Temp': 90.66,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Develi',
#   'Country': 'TR',
#   'Date': '2022-07-18 04:43:01',
#   'Lat': 38.3906,
#   'Lng': 35.4922,
#   'Max Temp': 63.75,
#   'Humidity': 71,
#   'Cloudiness': 57,
#   'Wind Speed': 6.67,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sinfra',
#   'Country': 'CI',
#   'Date': '2022-07-18 04:43:01',
#   'Lat': 6.6167,
#   'Lng': -5.9167,
#   'Max Temp': 68.32,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lewisville',
#   'Country': 'US',
#   'Date': '2022-07-18 04:39:49',
#   'Lat': 33.0462,
#   'Lng': -96.9942,
#   'Max Temp': 94.93,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tarpon Springs',
#   'Country': 'US',
#   'Date': '2022-07-18 04:43:02',
#   'Lat': 28.1461,
#   'Lng': -82.7568,
#   'Max Temp': 82.42,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chililabombwe',
#   'Country': 'ZM',
#   'Date': '2022-07-18 04:43:02',
#   'Lat': -12.3648,
#   'Lng': 27.8229,
#   'Max Temp': 47.91,
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'San Miguel',
#   'Country': 'SV',
#   'Date': '2022-07-18 04:43:03',
#   'Lat': 13.4833,
#   'Lng': -88.1833,
#   'Max Temp': 75.18,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 1.95,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Arrifes',
#   'Country': 'PT',
#   'Date': '2022-07-18 04:43:03',
#   'Lat': 37.7667,
#   'Lng': -25.7,
#   'Max Temp': 72.23,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Champagnole',
#   'Country': 'FR',
#   'Date': '2022-07-18 04:43:03',
#   'Lat': 46.7445,
#   'Lng': 5.9135,
#   'Max Temp': 66.43,
#   'Humidity': 42,
#   'Cloudiness': 15,
#   'Wind Speed': 5.26,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Date': '2022-07-18 04:43:04',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 49.73,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Dergachi',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:04',
#   'Lat': 51.2328,
#   'Lng': 48.7659,
#   'Max Temp': 77.49,
#   'Humidity': 58,
#   'Cloudiness': 4,
#   'Wind Speed': 10.2,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Date': '2022-07-18 04:41:17',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 73.94,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:04',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 62.6,
#   'Humidity': 80,
#   'Cloudiness': 89,
#   'Wind Speed': 9.89,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Wanaka',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:43:05',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 49.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ojinaga',
#   'Country': 'MX',
#   'Date': '2022-07-18 04:43:05',
#   'Lat': 29.5667,
#   'Lng': -104.4167,
#   'Max Temp': 93.42,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Perevoz',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:05',
#   'Lat': 55.5961,
#   'Lng': 44.5446,
#   'Max Temp': 68.11,
#   'Humidity': 79,
#   'Cloudiness': 83,
#   'Wind Speed': 5.06,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chunoyar',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:06',
#   'Lat': 57.4467,
#   'Lng': 97.3217,
#   'Max Temp': 60.76,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.66,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chebsara',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:06',
#   'Lat': 59.2002,
#   'Lng': 38.8356,
#   'Max Temp': 58.33,
#   'Humidity': 73,
#   'Cloudiness': 45,
#   'Wind Speed': 3.22,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Date': '2022-07-18 04:43:06',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 53.55,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Young',
#   'Country': 'UY',
#   'Date': '2022-07-18 04:43:07',
#   'Lat': -32.6833,
#   'Lng': -57.6333,
#   'Max Temp': 39.11,
#   'Humidity': 92,
#   'Cloudiness': 6,
#   'Wind Speed': 7.36,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Cumberland',
#   'Country': 'US',
#   'Date': '2022-07-18 04:43:07',
#   'Lat': 35.0502,
#   'Lng': -78.8664,
#   'Max Temp': 80.49,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Juigalpa',
#   'Country': 'NI',
#   'Date': '2022-07-18 04:43:07',
#   'Lat': 12.1063,
#   'Lng': -85.3645,
#   'Max Temp': 75.85,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ibipeba',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:43:08',
#   'Lat': -11.6408,
#   'Lng': -42.0111,
#   'Max Temp': 59.18,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 6.58,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:08',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 63.21,
#   'Humidity': 48,
#   'Cloudiness': 91,
#   'Wind Speed': 1.21,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ornes',
#   'Country': 'NO',
#   'Date': '2022-07-18 04:43:08',
#   'Lat': 66.8689,
#   'Lng': 13.7078,
#   'Max Temp': 52.7,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Current Description': 'light rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:43:08',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 85.98,
#   'Humidity': 28,
#   'Cloudiness': 27,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ngunguru',
#   'Country': 'NZ',
#   'Date': '2022-07-18 04:43:09',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 57.99,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.88,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Castelo Do Piaui',
#   'Country': 'BR',
#   'Date': '2022-07-18 04:43:09',
#   'Lat': -5.3222,
#   'Lng': -41.5525,
#   'Max Temp': 71.71,
#   'Humidity': 66,
#   'Cloudiness': 12,
#   'Wind Speed': 2.53,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Date': '2022-07-18 04:43:09',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 78.57,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Shevchenkove',
#   'Country': 'UA',
#   'Date': '2022-07-18 04:43:10',
#   'Lat': 49.6959,
#   'Lng': 37.1735,
#   'Max Temp': 61.07,
#   'Humidity': 68,
#   'Cloudiness': 8,
#   'Wind Speed': 12.3,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Elk Plain',
#   'Country': 'US',
#   'Date': '2022-07-18 04:43:10',
#   'Lat': 47.0532,
#   'Lng': -122.3976,
#   'Max Temp': 63.16,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Melfi',
#   'Country': 'IT',
#   'Date': '2022-07-18 04:43:10',
#   'Lat': 40.9965,
#   'Lng': 15.6514,
#   'Max Temp': 70.48,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 2.44,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Date': '2022-07-18 04:43:11',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 44.17,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Current Description': 'overcast clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Aliwal North',
#   'Country': 'ZA',
#   'Date': '2022-07-18 04:43:11',
#   'Lat': -30.6937,
#   'Lng': 26.7114,
#   'Max Temp': 41.81,
#   'Humidity': 51,
#   'Cloudiness': 2,
#   'Wind Speed': 3.74,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Estevan',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:43:11',
#   'Lat': 49.1334,
#   'Lng': -102.9842,
#   'Max Temp': 71.94,
#   'Humidity': 57,
#   'Cloudiness': 81,
#   'Wind Speed': 19.62,
#   'Current Description': 'broken clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Tekirdag',
#   'Country': 'TR',
#   'Date': '2022-07-18 04:43:11',
#   'Lat': 40.978,
#   'Lng': 27.5085,
#   'Max Temp': 72.75,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 17.83,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Ottawa',
#   'Country': 'CA',
#   'Date': '2022-07-18 04:41:19',
#   'Lat': 45.4112,
#   'Lng': -75.6981,
#   'Max Temp': 69.58,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.71,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Chokwe',
#   'Country': 'MZ',
#   'Date': '2022-07-18 04:43:12',
#   'Lat': -24.5333,
#   'Lng': 32.9833,
#   'Max Temp': 60.64,
#   'Humidity': 96,
#   'Cloudiness': 3,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Lobanovo',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:12',
#   'Lat': 57.8595,
#   'Lng': 56.3026,
#   'Max Temp': 73.31,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Port Moresby',
#   'Country': 'PG',
#   'Date': '2022-07-18 04:41:51',
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 83.62,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'haze',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Kijang',
#   'Country': 'KR',
#   'Date': '2022-07-18 04:43:13',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 74.93,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Current Description': 'moderate rain',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Esso',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:13',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp': 78.57,
#   'Humidity': 45,
#   'Cloudiness': 12,
#   'Wind Speed': 7.96,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Date': '2022-07-18 04:43:13',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 68.76,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 11.32,
#   'Current Description': 'clear sky',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0},
#  {'City': 'Borogontsy',
#   'Country': 'RU',
#   'Date': '2022-07-18 04:43:14',
#   'Lat': 62.6683,
#   'Lng': 131.1683,
#   'Max Temp': 90.3,
#   'Humidity': 35,
#   'Cloudiness': 14,
#   'Wind Speed': 6.29,
#   'Current Description': 'few clouds',
#   'Rain inches (last 3hrs)': 0.0,
#   'Snow inches (last 3hrs)': 0.0}]

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.6001  -73.9662     73.67        78         100
# 1     Rikitea      PF -23.1203 -134.9692     74.43        77          99
# 2   Jamestown      US  42.0970  -79.2353     67.01        84         100
# 3  Nouadhibou      MR  20.9310  -17.0347     71.58        83          95
# 4    Flinders      AU -34.5833  150.8552     62.38        45           2
#
#    Wind Speed Current Description
# 0        2.37     overcast clouds
# 1       15.30          light rain
# 2       11.99       moderate rain
# 3       26.46     overcast clouds
# 4       10.00           clear sky
