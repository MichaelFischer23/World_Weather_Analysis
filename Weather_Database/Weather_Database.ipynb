# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description,
                              "Rain inches (last 3hrs)":city_rain,
                                "Snow inches (last 3hrs)":city_snow})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | killybegs
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | salalah
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | po
# City not found. Skipping...
# Processing Record 8 of Set 1 | pangnirtung
# Processing Record 9 of Set 1 | zitacuaro
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 1 | lorengau
# Processing Record 13 of Set 1 | bay roberts
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | teguise
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | valley city
# Processing Record 18 of Set 1 | oregon city
# Processing Record 19 of Set 1 | maravilha
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | lago da pedra
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | biak
# Processing Record 25 of Set 1 | saurimo
# Processing Record 26 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 1 | gat
# Processing Record 28 of Set 1 | luderitz
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 33 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 1 | port-gentil
# Processing Record 35 of Set 1 | arsenyev
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | ulaangom
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | quatre cocos
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | lakatoro
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | siguiri
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | khanewal
# Processing Record 3 of Set 2 | byron bay
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | garissa
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | balkanabat
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | atar
# Processing Record 18 of Set 2 | okhotsk
# Processing Record 19 of Set 2 | hami
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | asyut
# Processing Record 22 of Set 2 | zaria
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | garelochhead
# Processing Record 26 of Set 2 | lixourion
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | tuatapere
# Processing Record 29 of Set 2 | annau
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | vardo
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | rovaniemi
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | khudumelapye
# Processing Record 41 of Set 2 | saint-pierre
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | san juan de los morros
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | tanda
# Processing Record 47 of Set 2 | mahon
# Processing Record 48 of Set 2 | tucurui
# Processing Record 49 of Set 2 | chumikan
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | rzhaksa
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | assiniboia
# Processing Record 7 of Set 3 | karratha
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | berbera
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 3 | puerto cabezas
# Processing Record 16 of Set 3 | cayenne
# Processing Record 17 of Set 3 | corpus christi
# Processing Record 18 of Set 3 | kuryk
# Processing Record 19 of Set 3 | meulaboh
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | werota
# Processing Record 23 of Set 3 | hasaki
# Processing Record 24 of Set 3 | harper
# Processing Record 25 of Set 3 | sokol
# Processing Record 26 of Set 3 | belmonte
# Processing Record 27 of Set 3 | roma
# Processing Record 28 of Set 3 | nisporeni
# Processing Record 29 of Set 3 | vestmannaeyjar
# Processing Record 30 of Set 3 | muzquiz
# City not found. Skipping...
# Processing Record 31 of Set 3 | burica
# City not found. Skipping...
# Processing Record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | hovd
# Processing Record 35 of Set 3 | nizhniy ingash
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | labuhan
# Processing Record 39 of Set 3 | tarnogskiy gorodok
# Processing Record 40 of Set 3 | awjilah
# Processing Record 41 of Set 3 | portland
# Processing Record 42 of Set 3 | neuquen
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | edd
# Processing Record 47 of Set 3 | bereda
# Processing Record 48 of Set 3 | taltal
# Processing Record 49 of Set 3 | opuwo
# Processing Record 50 of Set 3 | tela
# Processing Record 1 of Set 4 | greytown
# Processing Record 2 of Set 4 | elban
# Processing Record 3 of Set 4 | platonovka
# Processing Record 4 of Set 4 | valentin gomez farias
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | cherskiy
# Processing Record 8 of Set 4 | yar-sale
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | bambari
# Processing Record 11 of Set 4 | tecoanapa
# Processing Record 12 of Set 4 | comodoro rivadavia
# Processing Record 13 of Set 4 | tual
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 4 | ghanzi
# Processing Record 17 of Set 4 | dongsheng
# Processing Record 18 of Set 4 | roald
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | hendek
# Processing Record 21 of Set 4 | hobart
# Processing Record 22 of Set 4 | pangody
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | santa barbara
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | constitucion
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | sal rei
# Processing Record 31 of Set 4 | goure
# Processing Record 32 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | carahue
# Processing Record 35 of Set 4 | rioblanco
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | glenwood springs
# Processing Record 38 of Set 4 | mehamn
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | ballina
# Processing Record 43 of Set 4 | goderich
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | kununurra
# Processing Record 46 of Set 4 | khandyga
# Processing Record 47 of Set 4 | spring valley
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | stornoway
# Processing Record 1 of Set 5 | kenai
# Processing Record 2 of Set 5 | sur
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | lupsanu
# Processing Record 6 of Set 5 | husavik
# Processing Record 7 of Set 5 | antofagasta
# Processing Record 8 of Set 5 | tessalit
# Processing Record 9 of Set 5 | tuktoyaktuk
# Processing Record 10 of Set 5 | kudahuvadhoo
# Processing Record 11 of Set 5 | manzhouli
# Processing Record 12 of Set 5 | burnie
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | teya
# Processing Record 15 of Set 5 | koygorodok
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | mundo nuevo
# Processing Record 18 of Set 5 | bafq
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | cape canaveral
# Processing Record 21 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 5 | broken hill
# Processing Record 23 of Set 5 | paracuru
# Processing Record 24 of Set 5 | thompson
# Processing Record 25 of Set 5 | grindavik
# Processing Record 26 of Set 5 | adolfo lopez mateos
# Processing Record 27 of Set 5 | waddan
# Processing Record 28 of Set 5 | srednyaya yelyuzan
# Processing Record 29 of Set 5 | makakilo city
# Processing Record 30 of Set 5 | mbini
# Processing Record 31 of Set 5 | pimentel
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | san carlos de bariloche
# Processing Record 34 of Set 5 | alice springs
# Processing Record 35 of Set 5 | sambava
# Processing Record 36 of Set 5 | gamba
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | berlevag
# Processing Record 39 of Set 5 | coalinga
# Processing Record 40 of Set 5 | shingu
# Processing Record 41 of Set 5 | phuket
# Processing Record 42 of Set 5 | krugersdorp
# Processing Record 43 of Set 5 | merauke
# Processing Record 44 of Set 5 | faya
# Processing Record 45 of Set 5 | cairns
# Processing Record 46 of Set 5 | saint-francois
# Processing Record 47 of Set 5 | rockland
# Processing Record 48 of Set 5 | yulara
# Processing Record 49 of Set 5 | paita
# Processing Record 50 of Set 5 | sitka
# Processing Record 1 of Set 6 | cerrito
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | mao
# Processing Record 5 of Set 6 | castro
# Processing Record 6 of Set 6 | westport
# Processing Record 7 of Set 6 | pavlysh
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | kwekwe
# Processing Record 11 of Set 6 | san cristobal
# Processing Record 12 of Set 6 | kalmunai
# Processing Record 13 of Set 6 | yarada
# Processing Record 14 of Set 6 | estremoz
# Processing Record 15 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | port augusta
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | mali
# Processing Record 20 of Set 6 | pechenga
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | nakskov
# Processing Record 23 of Set 6 | sint anthonis
# Processing Record 24 of Set 6 | georgiyevka
# Processing Record 25 of Set 6 | general pico
# Processing Record 26 of Set 6 | kapit
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | inuvik
# Processing Record 29 of Set 6 | matay
# Processing Record 30 of Set 6 | tupik
# Processing Record 31 of Set 6 | baghdad
# Processing Record 32 of Set 6 | inhambane
# Processing Record 33 of Set 6 | belle fourche
# Processing Record 34 of Set 6 | yumen
# Processing Record 35 of Set 6 | sopot
# Processing Record 36 of Set 6 | nhulunbuy
# Processing Record 37 of Set 6 | high level
# Processing Record 38 of Set 6 | nang rong
# Processing Record 39 of Set 6 | bunia
# Processing Record 40 of Set 6 | dukat
# Processing Record 41 of Set 6 | san andres
# Processing Record 42 of Set 6 | diamantino
# Processing Record 43 of Set 6 | kupang
# Processing Record 44 of Set 6 | xam nua
# Processing Record 45 of Set 6 | gigmoto
# Processing Record 46 of Set 6 | yengema
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | ponta do sol
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | liling
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | desaguadero
# Processing Record 4 of Set 7 | vicuna
# Processing Record 5 of Set 7 | susanville
# Processing Record 6 of Set 7 | severo-kurilsk
# Processing Record 7 of Set 7 | zdvinsk
# Processing Record 8 of Set 7 | garwolin
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | amarante do maranhao
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | kamenka
# Processing Record 14 of Set 7 | tura
# Processing Record 15 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | shebalino
# Processing Record 18 of Set 7 | buala
# Processing Record 19 of Set 7 | ndioum
# Processing Record 20 of Set 7 | qandala
# Processing Record 21 of Set 7 | nyrob
# Processing Record 22 of Set 7 | nsanje
# Processing Record 23 of Set 7 | athabasca
# Processing Record 24 of Set 7 | taoudenni
# Processing Record 25 of Set 7 | konza
# Processing Record 26 of Set 7 | harrisburg
# Processing Record 27 of Set 7 | samarai
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | dingle
# Processing Record 30 of Set 7 | kjollefjord
# Processing Record 31 of Set 7 | olafsvik
# Processing Record 32 of Set 7 | pemba
# Processing Record 33 of Set 7 | nicoya
# Processing Record 34 of Set 7 | west wendover
# Processing Record 35 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 7 | akcaabat
# Processing Record 37 of Set 7 | dickinson
# Processing Record 38 of Set 7 | bairiki
# Processing Record 39 of Set 7 | yuksekova
# Processing Record 40 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 41 of Set 7 | spornoye
# Processing Record 42 of Set 7 | pandan niog
# Processing Record 43 of Set 7 | half moon bay
# Processing Record 44 of Set 7 | talaya
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | karwar
# Processing Record 47 of Set 7 | verkhoyansk
# Processing Record 48 of Set 7 | banjar
# Processing Record 49 of Set 7 | zadar
# Processing Record 50 of Set 7 | sterling
# Processing Record 1 of Set 8 | synya
# Processing Record 2 of Set 8 | salinas
# Processing Record 3 of Set 8 | madona
# Processing Record 4 of Set 8 | ust-nera
# Processing Record 5 of Set 8 | adrar
# Processing Record 6 of Set 8 | keti bandar
# Processing Record 7 of Set 8 | cam ranh
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | praia
# Processing Record 10 of Set 8 | mocuba
# Processing Record 11 of Set 8 | hobyo
# Processing Record 12 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 8 | orchard homes
# Processing Record 14 of Set 8 | noshiro
# Processing Record 15 of Set 8 | nyurba
# Processing Record 16 of Set 8 | wanning
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | funadhoo
# Processing Record 19 of Set 8 | irtyshskiy
# Processing Record 20 of Set 8 | santa isabel
# Processing Record 21 of Set 8 | belle glade
# Processing Record 22 of Set 8 | yeniseysk
# Processing Record 23 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 8 | raudeberg
# Processing Record 25 of Set 8 | srednekolymsk
# Processing Record 26 of Set 8 | basqal
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | bograd
# Processing Record 29 of Set 8 | itapua poty
# City not found. Skipping...
# Processing Record 30 of Set 8 | vestmanna
# Processing Record 31 of Set 8 | tazovskiy
# Processing Record 32 of Set 8 | hornepayne
# Processing Record 33 of Set 8 | diplo
# Processing Record 34 of Set 8 | salisbury
# Processing Record 35 of Set 8 | karakol
# Processing Record 36 of Set 8 | bilibino
# Processing Record 37 of Set 8 | urcos
# Processing Record 38 of Set 8 | honningsvag
# Processing Record 39 of Set 8 | manaure
# Processing Record 40 of Set 8 | hervey bay
# Processing Record 41 of Set 8 | marshall
# Processing Record 42 of Set 8 | bheramara
# Processing Record 43 of Set 8 | hirara
# Processing Record 44 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 45 of Set 8 | muros
# Processing Record 46 of Set 8 | sakakah
# Processing Record 47 of Set 8 | daru
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | esperantina
# Processing Record 50 of Set 8 | muyezerskiy
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | almaya
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | podgornoye
# Processing Record 5 of Set 9 | souillac
# Processing Record 6 of Set 9 | xinmin
# Processing Record 7 of Set 9 | itaperuna
# Processing Record 8 of Set 9 | tahe
# Processing Record 9 of Set 9 | gauripur
# Processing Record 10 of Set 9 | sao gabriel da cachoeira
# Processing Record 11 of Set 9 | port hardy
# Processing Record 12 of Set 9 | kutum
# Processing Record 13 of Set 9 | havoysund
# Processing Record 14 of Set 9 | kamyaran
# Processing Record 15 of Set 9 | kisanga
# Processing Record 16 of Set 9 | el alto
# Processing Record 17 of Set 9 | alofi
# Processing Record 18 of Set 9 | kinanah
# City not found. Skipping...
# Processing Record 19 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 9 | tilichiki
# Processing Record 21 of Set 9 | itaituba
# Processing Record 22 of Set 9 | kandrian
# Processing Record 23 of Set 9 | mnogovershinnyy
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | paamiut
# Processing Record 26 of Set 9 | aitape
# Processing Record 27 of Set 9 | mana
# Processing Record 28 of Set 9 | kemijarvi
# Processing Record 29 of Set 9 | turukhansk
# Processing Record 30 of Set 9 | jiangkou
# Processing Record 31 of Set 9 | namatanai
# Processing Record 32 of Set 9 | aliaga
# Processing Record 33 of Set 9 | contamana
# Processing Record 34 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 9 | maldonado
# Processing Record 36 of Set 9 | save
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | luganville
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | tongliao
# Processing Record 41 of Set 9 | kaman
# Processing Record 42 of Set 9 | ust-kut
# Processing Record 43 of Set 9 | syracuse
# Processing Record 44 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | wilmington
# Processing Record 47 of Set 9 | juba
# Processing Record 48 of Set 9 | milkovo
# Processing Record 49 of Set 9 | arbagar
# Processing Record 50 of Set 9 | alta floresta
# Processing Record 1 of Set 10 | nizwa
# Processing Record 2 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 10 | warman
# Processing Record 4 of Set 10 | severomuysk
# Processing Record 5 of Set 10 | falkenstein
# Processing Record 6 of Set 10 | mandalgovi
# Processing Record 7 of Set 10 | olinda
# Processing Record 8 of Set 10 | henties bay
# Processing Record 9 of Set 10 | moyobamba
# Processing Record 10 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 10 | dauphin
# Processing Record 13 of Set 10 | qaqortoq
# Processing Record 14 of Set 10 | san patricio
# Processing Record 15 of Set 10 | anadyr
# Processing Record 16 of Set 10 | port blair
# Processing Record 17 of Set 10 | valparaiso
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | santa cruz
# Processing Record 20 of Set 10 | gornopravdinsk
# Processing Record 21 of Set 10 | acapulco
# Processing Record 22 of Set 10 | kargasok
# Processing Record 23 of Set 10 | dzhebariki-khaya
# Processing Record 24 of Set 10 | sokoni
# Processing Record 25 of Set 10 | ilulissat
# Processing Record 26 of Set 10 | prainha
# Processing Record 27 of Set 10 | magadan
# Processing Record 28 of Set 10 | sayat
# Processing Record 29 of Set 10 | sibolga
# Processing Record 30 of Set 10 | summerville
# Processing Record 31 of Set 10 | sao filipe
# Processing Record 32 of Set 10 | klaksvik
# Processing Record 33 of Set 10 | yamada
# Processing Record 34 of Set 10 | alirajpur
# Processing Record 35 of Set 10 | yangshe
# Processing Record 36 of Set 10 | isangel
# Processing Record 37 of Set 10 | sioux lookout
# Processing Record 38 of Set 10 | kozhva
# Processing Record 39 of Set 10 | buin
# Processing Record 40 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | mancheral
# Processing Record 42 of Set 10 | beloha
# Processing Record 43 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 10 | sao miguel do araguaia
# Processing Record 45 of Set 10 | great yarmouth
# Processing Record 46 of Set 10 | aklavik
# Processing Record 47 of Set 10 | vanavara
# Processing Record 48 of Set 10 | san-pedro
# Processing Record 49 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | leshukonskoye
# Processing Record 1 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 2 of Set 11 | bac lieu
# Processing Record 3 of Set 11 | hay river
# Processing Record 4 of Set 11 | methoni
# Processing Record 5 of Set 11 | san angelo
# Processing Record 6 of Set 11 | yatou
# Processing Record 7 of Set 11 | makat
# Processing Record 8 of Set 11 | naze
# Processing Record 9 of Set 11 | mackenzie
# Processing Record 10 of Set 11 | bobcaygeon
# Processing Record 11 of Set 11 | rio grande
# Processing Record 12 of Set 11 | moussoro
# Processing Record 13 of Set 11 | brae
# Processing Record 14 of Set 11 | itoman
# Processing Record 15 of Set 11 | buraydah
# Processing Record 16 of Set 11 | vysokogornyy
# Processing Record 17 of Set 11 | fomboni
# Processing Record 18 of Set 11 | novyy urengoy
# Processing Record 19 of Set 11 | praya
# Processing Record 20 of Set 11 | oranjemund
# Processing Record 21 of Set 11 | benito juarez
# Processing Record 22 of Set 11 | sao desiderio
# Processing Record 23 of Set 11 | sangar
# Processing Record 24 of Set 11 | rock sound
# Processing Record 25 of Set 11 | basco
# Processing Record 26 of Set 11 | atherton
# Processing Record 27 of Set 11 | loa janan
# Processing Record 28 of Set 11 | port arthur
# Processing Record 29 of Set 11 | pitanga
# Processing Record 30 of Set 11 | oktyabrskoye
# Processing Record 31 of Set 11 | sorong
# Processing Record 32 of Set 11 | saint-leu
# Processing Record 33 of Set 11 | bonnyville
# Processing Record 34 of Set 11 | mauriti
# Processing Record 35 of Set 11 | sondrio
# Processing Record 36 of Set 11 | thaba-tseka
# Processing Record 37 of Set 11 | jalor
# Processing Record 38 of Set 11 | flin flon
# Processing Record 39 of Set 11 | rawson
# Processing Record 40 of Set 11 | qingdao
# Processing Record 41 of Set 11 | marsa matruh
# Processing Record 42 of Set 11 | tezu
# Processing Record 43 of Set 11 | lubaczow
# Processing Record 44 of Set 11 | domoni
# Processing Record 45 of Set 11 | chingirlau
# Processing Record 46 of Set 11 | jega
# Processing Record 47 of Set 11 | aksarka
# Processing Record 48 of Set 11 | casablanca
# Processing Record 49 of Set 11 | teahupoo
# Processing Record 50 of Set 11 | manono
# Processing Record 1 of Set 12 | belyy yar
# Processing Record 2 of Set 12 | tamiahua
# Processing Record 3 of Set 12 | chany
# Processing Record 4 of Set 12 | thinadhoo
# Processing Record 5 of Set 12 | pryozerne
# Processing Record 6 of Set 12 | najran
# Processing Record 7 of Set 12 | fort nelson
# Processing Record 8 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 12 | nalut
# Processing Record 10 of Set 12 | villa carlos paz
# Processing Record 11 of Set 12 | bondoukou
# Processing Record 12 of Set 12 | mirnyy
# Processing Record 13 of Set 12 | severo-yeniseyskiy
# Processing Record 14 of Set 12 | eenhana
# Processing Record 15 of Set 12 | son la
# Processing Record 16 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 17 of Set 12 | saint-georges
# Processing Record 18 of Set 12 | grootfontein
# Processing Record 19 of Set 12 | lasa
# Processing Record 20 of Set 12 | champerico
# Processing Record 21 of Set 12 | carutapera
# Processing Record 22 of Set 12 | sisimiut
# Processing Record 23 of Set 12 | venado
# Processing Record 24 of Set 12 | vega de alatorre
# Processing Record 25 of Set 12 | alappuzha
# Processing Record 26 of Set 12 | araguaina
# Processing Record 27 of Set 12 | lere
# Processing Record 28 of Set 12 | mangla
# Processing Record 29 of Set 12 | emba
# Processing Record 30 of Set 12 | jalingo
# Processing Record 31 of Set 12 | solok
# Processing Record 32 of Set 12 | dharur
# Processing Record 33 of Set 12 | luwingu
# Processing Record 34 of Set 12 | cabedelo
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | sooke
# Processing Record 37 of Set 12 | talcahuano
# Processing Record 38 of Set 12 | santiago del estero
# Processing Record 39 of Set 12 | linhares
# Processing Record 40 of Set 12 | dudinka
# Processing Record 41 of Set 12 | sept-iles
# Processing Record 42 of Set 12 | sokoto
# Processing Record 43 of Set 12 | ugoofaaru
# Processing Record 44 of Set 12 | cap malheureux
# Processing Record 45 of Set 12 | worland
# Processing Record 46 of Set 12 | cabo rojo
# Processing Record 47 of Set 12 | silvania
# Processing Record 48 of Set 12 | xixiang
# Processing Record 49 of Set 12 | mae sai
# Processing Record 50 of Set 12 | sete lagoas
# Processing Record 1 of Set 13 | novolvovsk
# City not found. Skipping...
# Processing Record 2 of Set 13 | tiznit
# Processing Record 3 of Set 13 | zabid
# Processing Record 4 of Set 13 | maniitsoq
# Processing Record 5 of Set 13 | mwinilunga
# Processing Record 6 of Set 13 | yining
# Processing Record 7 of Set 13 | santa maria
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | bilma
# Processing Record 10 of Set 13 | ajaccio
# Processing Record 11 of Set 13 | murgab
# Processing Record 12 of Set 13 | longido
# Processing Record 13 of Set 13 | mitsamiouli
# Processing Record 14 of Set 13 | fare
# Processing Record 15 of Set 13 | omboue
# Processing Record 16 of Set 13 | bibbiena
# Processing Record 17 of Set 13 | kholodnyy
# Processing Record 18 of Set 13 | saulkrasti
# Processing Record 19 of Set 13 | wexford
# Processing Record 20 of Set 13 | celestun
# Processing Record 21 of Set 13 | varhaug
# Processing Record 22 of Set 13 | arica
# Processing Record 23 of Set 13 | prince rupert
# Processing Record 24 of Set 13 | bundibugyo
# Processing Record 25 of Set 13 | petrokamenskoye
# Processing Record 26 of Set 13 | talavera de la reina
# Processing Record 27 of Set 13 | golden
# Processing Record 28 of Set 13 | gizo
# Processing Record 29 of Set 13 | torfyanoy
# Processing Record 30 of Set 13 | manukan
# Processing Record 31 of Set 13 | kuytun
# Processing Record 32 of Set 13 | sabang
# Processing Record 33 of Set 13 | yei
# Processing Record 34 of Set 13 | santander
# Processing Record 35 of Set 13 | ipameri
# Processing Record 36 of Set 13 | salzwedel
# Processing Record 37 of Set 13 | naryan-mar
# Processing Record 38 of Set 13 | dalbandin
# Processing Record 39 of Set 13 | skagen
# Processing Record 40 of Set 13 | darhan
# Processing Record 41 of Set 13 | sibenik
# Processing Record 42 of Set 13 | cheney
# Processing Record 43 of Set 13 | zhetysay
# Processing Record 44 of Set 13 | jacqueville
# Processing Record 45 of Set 13 | tres lagoas
# Processing Record 46 of Set 13 | alyangula
# Processing Record 47 of Set 13 | the valley
# Processing Record 48 of Set 13 | veisiejai
# Processing Record 49 of Set 13 | rayong
# Processing Record 50 of Set 13 | wana
# Processing Record 1 of Set 14 | sawtell
# Processing Record 2 of Set 14 | tarabuco
# Processing Record 3 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 14 | shchors
# Processing Record 5 of Set 14 | dali
# Processing Record 6 of Set 14 | gunjur
# Processing Record 7 of Set 14 | xai-xai
# Processing Record 8 of Set 14 | rudraprayag
# Processing Record 9 of Set 14 | iisalmi
# Processing Record 10 of Set 14 | skegness
# Processing Record 11 of Set 14 | wladyslawowo
# Processing Record 12 of Set 14 | kathu
# Processing Record 13 of Set 14 | vanimo
# Processing Record 14 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 14 | barsi
# Processing Record 16 of Set 14 | waipawa
# Processing Record 17 of Set 14 | catamarca
# Processing Record 18 of Set 14 | ayan
# Processing Record 19 of Set 14 | liverpool
# Processing Record 20 of Set 14 | liberta
# Processing Record 21 of Set 14 | tokmak
# Processing Record 22 of Set 14 | sidi ali
# Processing Record 23 of Set 14 | caraballeda
# Processing Record 24 of Set 14 | hambantota
# Processing Record 25 of Set 14 | touros
# Processing Record 26 of Set 14 | kosh-agach
# Processing Record 27 of Set 14 | catarman
# Processing Record 28 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 29 of Set 14 | bandarbeyla
# Processing Record 30 of Set 14 | madruga
# Processing Record 31 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 14 | wangqing
# Processing Record 33 of Set 14 | pulaski
# Processing Record 34 of Set 14 | knoxville
# Processing Record 35 of Set 14 | qinzhou
# Processing Record 36 of Set 14 | mbarara
# Processing Record 37 of Set 14 | safaga
# Processing Record 38 of Set 14 | porto walter
# Processing Record 39 of Set 14 | humaita
# Processing Record 40 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 14 | rio gallegos
# Processing Record 42 of Set 14 | galle
# Processing Record 43 of Set 14 | savonlinna
# Processing Record 44 of Set 14 | moscow
# Processing Record 45 of Set 14 | zhigansk
# Processing Record 46 of Set 14 | maxixe
# Processing Record 47 of Set 14 | parrita
# Processing Record 48 of Set 14 | saint-pacome
# City not found. Skipping...
# Processing Record 49 of Set 14 | ostrovnoy
# Processing Record 50 of Set 14 | puerto del rosario
# Processing Record 1 of Set 15 | sao paulo de olivenca
# Processing Record 2 of Set 15 | xinyu
# Processing Record 3 of Set 15 | beringovskiy
# Processing Record 4 of Set 15 | plouzane
# Processing Record 5 of Set 15 | gbarnga
# Processing Record 6 of Set 15 | chapais
# Processing Record 7 of Set 15 | gisborne
# Processing Record 8 of Set 15 | aguimes
# Processing Record 9 of Set 15 | machico
# Processing Record 10 of Set 15 | pakenham
# Processing Record 11 of Set 15 | shubarshi
# Processing Record 12 of Set 15 | shitanjing
# Processing Record 13 of Set 15 | gazanjyk
# Processing Record 14 of Set 15 | beyneu
# Processing Record 15 of Set 15 | san jeronimo
# Processing Record 16 of Set 15 | cap-aux-meules
# Processing Record 17 of Set 15 | porto novo
# Processing Record 18 of Set 15 | vung tau
# Processing Record 19 of Set 15 | marystown
# Processing Record 20 of Set 15 | boyolangu
# Processing Record 21 of Set 15 | ilebo
# Processing Record 22 of Set 15 | fairbanks
# Processing Record 23 of Set 15 | mezen
# Processing Record 24 of Set 15 | winnenden
# Processing Record 25 of Set 15 | pierre
# Processing Record 26 of Set 15 | collie
# Processing Record 27 of Set 15 | wadi musa
# Processing Record 28 of Set 15 | kurdzhinovo
# Processing Record 29 of Set 15 | jalu
# Processing Record 30 of Set 15 | road town
# Processing Record 31 of Set 15 | wewak
# Processing Record 32 of Set 15 | peniche
# Processing Record 33 of Set 15 | borgarnes
# Processing Record 34 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 15 | kokoda
# Processing Record 36 of Set 15 | kargala
# Processing Record 37 of Set 15 | san quintin
# Processing Record 38 of Set 15 | bathsheba
# Processing Record 39 of Set 15 | tabory
# Processing Record 40 of Set 15 | jacareacanga
# Processing Record 41 of Set 15 | chanasma
# Processing Record 42 of Set 15 | ekibastuz
# Processing Record 43 of Set 15 | balkhash
# Processing Record 44 of Set 15 | nagsabaran
# City not found. Skipping...
# Processing Record 45 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 15 | arlit
# Processing Record 47 of Set 15 | nanzhang
# Processing Record 48 of Set 15 | vila velha
# Processing Record 49 of Set 15 | ambalavao
# Processing Record 50 of Set 15 | regeneracao
# Processing Record 1 of Set 16 | chulman
# Processing Record 2 of Set 16 | tebingtinggi
# Processing Record 3 of Set 16 | vilyuysk
# Processing Record 4 of Set 16 | sant feliu de guixols
# Processing Record 5 of Set 16 | vondrozo
# Processing Record 6 of Set 16 | belyy
# Processing Record 7 of Set 16 | laramie
# Processing Record 8 of Set 16 | skerries
# Processing Record 9 of Set 16 | kalabo
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Killybegs      IE  54.6333   -8.4500     62.49        91         100
# 1   Busselton      AU -33.6500  115.3333     51.26        84           0
# 2   Geraldton      AU -28.7667  114.6000     52.21        93          27
# 3     Salalah      OM  17.0151   54.0924     77.09        94         100
# 4  Butaritari      KI   3.0707  172.7902     82.36        75          16
#
#    Wind Speed Current Description
# 0        7.72     overcast clouds
# 1        7.67           clear sky
# 2       11.50    scattered clouds
# 3        4.61     overcast clouds
# 4       19.77          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
